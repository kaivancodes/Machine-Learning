# %% [markdown]
# # SKLearn
# ## 25/7/24

# %% [markdown]
# ## Wine

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import load_wine
wine = load_wine()

# %%
wine_df = pd.DataFrame(data = wine.data,columns = wine.feature_names)
wine_df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
wine_df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
wine_df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
wine_df.tail()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 173        0.61                  0.52             1.06              7.7  0.64
# 174        0.75                  0.43             1.41              7.3  0.70
# 175        0.69                  0.43             1.35             10.2  0.59
# 176        0.68                  0.53             1.46              9.3  0.60
# 177        0.76                  0.56             1.35              9.2  0.61
#
# ...

# %% [markdown]
# ## KNN

# %%
x = wine.data
y = wine.target

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size = 0.3, random_state = 0)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn
# Out:
# KNeighborsClassifier()

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)

# %%
y_pred
# Out:
# array([0, 1, 1, 0, 1, 1, 0, 2, 1, 1, 0, 1, 0, 2, 0, 1, 0, 0, 1, 0, 1, 0,
#        1, 1, 1, 1, 1, 1, 2, 2, 0, 0, 2, 0, 0, 0, 1, 1, 1, 0, 2, 0, 1, 2,
#        1, 2, 1, 0, 2, 0, 2, 2, 0, 2])

# %%
from sklearn.metrics import accuracy_score
ask = accuracy_score(y_test, y_pred)*100
print("Test Data Accuracy:",ask)
# Out:
# Test Data Accuracy: 72.22222222222221

# %%
print("Test Data Accuracy: ", knn.score(x_test, y_test) * 100)
# Out:
# Test Data Accuracy:  72.22222222222221

# %%
knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[16  1  2]
#  [ 1 17  4]
#  [ 3  4  6]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82        19
#            1       0.77      0.77      0.77        22
#            2       0.50      0.46      0.48        13
#
#     accuracy                           0.72        54
#    macro avg       0.69      0.69      0.69        54
# weighted avg       0.72      0.72      0.72        54

# %%
sns.heatmap(cm,annot = True)
# Out:
# <Axes: >

# %%
sns.barplot(cm)
# Out:
# <Axes: >

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.datasets import load_wine
wine1 = load_wine()

# %%
wine_df1 = pd.DataFrame(data = wine.data,columns = wine.feature_names)
wine_df1
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
x = wine1.data
y = wine1.target

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
lr1 = LogisticRegression()
lr1
# Out:
# LogisticRegression()

# %%
lr1.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr1.predict(x_test)

# %%
asl = lr1.score(x_test, y_test) * 100
print("Test Data Accuracy:", asl)
# Out:
# Test Data Accuracy: 94.44444444444444

# %%
print("Test Accuracy:",accuracy_score(y_test,y_pred)*100)
# Out:
# Test Accuracy: 94.44444444444444

# %%
cm1 = confusion_matrix(y_test, y_pred)
print(cm1)
# Out:
# [[17  2  0]
#  [ 0 21  1]
#  [ 0  0 13]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94        19
#            1       0.91      0.95      0.93        22
#            2       0.93      1.00      0.96        13
#
#     accuracy                           0.94        54
#    macro avg       0.95      0.95      0.95        54
# weighted avg       0.95      0.94      0.94        54

# %%
sns.heatmap(cm1,annot = True)
# Out:
# <Axes: >

# %%
sns.barplot(cm1)
# Out:
# <Axes: >

# %%
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier()
clf
# Out:
# DecisionTreeClassifier()

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(x_test)

# %%
ast = accuracy_score(y_test,y_pred)*100

# %%
print("Train Data Accuracy: ",accuracy_score(y_train,clf.predict(x_train))*100)
print("Test Data Accuracy: ",ast)
# Out:
# Train Data Accuracy:  100.0
# Test Data Accuracy:  94.44444444444444

# %%
from sklearn.metrics import confusion_matrix
cm2 = confusion_matrix(y_test,y_pred)
cm2
# Out:
# array([[17,  2,  0],
#        [ 0, 21,  1],
#        [ 0,  0, 13]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94        19
#            1       0.91      0.95      0.93        22
#            2       0.93      1.00      0.96        13
#
#     accuracy                           0.94        54
#    macro avg       0.95      0.95      0.95        54
# weighted avg       0.95      0.94      0.94        54

# %%
sns.heatmap(cm2, annot = True)
# Out:
# <Axes: >

# %%
sns.barplot(cm2)
# Out:
# <Axes: >

# %%
from sklearn import tree
tree.plot_tree(clf)
# Out:
# [Text(0.5, 0.9, 'x[9] <= 3.82\ngini = 0.66\nsamples = 124\nvalue = [40, 49, 35]'),
#  Text(0.3, 0.7, 'x[12] <= 1002.5\ngini = 0.12\nsamples = 47\nvalue = [3.0, 44.0, 0.0]'),
#  Text(0.2, 0.5, 'x[2] <= 3.0\ngini = 0.043\nsamples = 45\nvalue = [1, 44, 0]'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 44\nvalue = [0, 44, 0]'),
#  Text(0.3, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.4, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.7, 0.7, 'x[6] <= 1.58\ngini = 0.558\nsamples = 77\nvalue = [37.0, 5.0, 35.0]'),
#  Text(0.6, 0.5, 'gini = 0.0\nsamples = 35\nvalue = [0, 0, 35]'),
#  Text(0.8, 0.5, 'x[12] <= 737.0\ngini = 0.21\nsamples = 42\nvalue = [37, 5, 0]'),
#  Text(0.7, 0.3, 'x[1] <= 3.92\ngini = 0.278\nsamples = 6\nvalue = [1, 5, 0]'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0]'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.9, 0.3, 'gini = 0.0\nsamples = 36\nvalue = [36, 0, 0]')]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report
rt_classifier = RandomForestClassifier(n_estimators = 100, random_state=81)
rt_classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=81)

# %%
y_pred=rt_classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm3 = confusion_matrix(y_test,y_pred)
cm3
# Out:
# array([[19,  0,  0],
#        [ 0, 21,  1],
#        [ 0,  0, 13]])

# %%
asr = accuracy_score(y_test,y_pred)*100
print("Test Data Accuracy:",asr)
# Out:
# Test Data Accuracy: 98.14814814814815

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      0.95      0.98        22
#            2       0.93      1.00      0.96        13
#
#     accuracy                           0.98        54
#    macro avg       0.98      0.98      0.98        54
# weighted avg       0.98      0.98      0.98        54

# %%
sns.heatmap(cm3, annot = True)
# Out:
# <Axes: >

# %%
sns.barplot(cm3)
# Out:
# <Axes: >

# %%
from matplotlib import style
style.use('ggplot')
plt.figure(figsize = (10, 7))
barwidth = 0.4
plt.bar('KNN', ask)
plt.bar('LR', asl)
plt.bar('Tree', ast)
plt.bar('RF', asr)
# Out:
# <BarContainer object of 1 artists>
